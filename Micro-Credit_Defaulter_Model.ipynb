# %%
#import libary for use method
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
#pandas
pd.set_option("display.max_rows",500)
pd.set_option("display.max_columns",500)

# %%
#loading dataset
customers = pd.read_csv('Data_file.csv',parse_dates=['pdate'])

# %%
#Viewing the first 5 lines of dataset
customers.head()
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 4      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                2.0                0.0              1539              2
# 1               20.0                0.0              5787              1
# 2                3.0                0.0              1539              1
# 3               41.0                0.0               947              0
# 4                4.0                0.0              2309              7
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# ...

# %%
#Viewing the last 5 lines of dataset
customers.tail()
# Out:
#         label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 209588      1  22758I85348   404.0    151.872333    151.872333   1089.19
# 209589      1  95583I84455  1075.0     36.936000     36.936000   1728.36
# 209590      1  28556I85350  1013.0  11843.111670  11904.350000   5861.83
# 209591      1  59712I82733  1732.0  12488.228330  12574.370000    411.83
# 209592      1  65061I85339  1581.0   4489.362000   4534.820000    483.92
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# 209588   1089.19                1.0                0.0              4048
# 209589   1728.36                4.0                0.0               773
# 209590   8893.20                3.0                0.0              1539
# 209591    984.58                2.0               38.0               773
# 209592    631.20               13.0                0.0              7526
#
#         cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# ...

# %%
# prints information about a DataFrame including the index dtype and columns, non-null values and memory usage.
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   msisdn                209593 non-null  object
#  2   aon                   209593 non-null  float64
#  3   daily_decr30          209593 non-null  float64
#  4   daily_decr90          209593 non-null  float64
#  5   rental30              209593 non-null  float64
#  6   rental90              209593 non-null  float64
#  7   last_rech_date_ma     209593 non-null  float64
#  8   last_rech_date_da     209593 non-null  float64
#  9   last_rech_amt_ma      209593 non-null  int64
#  10  cnt_ma_rech30         209593 non-null  int64
#  11  fr_ma_rech30          209593 non-null  float64
#  12  sumamnt_ma_rech30     209593 non-null  float64
#  13  medianamnt_ma_rech30  209593 non-null  float64
# ...

# %%
#Lets Understand the Columns Values
info = ["Flag indicating whether the user paid back the credit amount within 5 days of issuing the loan{1:success, 0:failure}",
        "mobile number of user",
        "age on cellular network in days",
        "Daily amount spent from main account, averaged over last 30 days (in Indonesian Rupiah)",
        "Daily amount spent from main account, averaged over last 90 days (in Indonesian Rupiah)",
        "Average main account balance over last 30 days",
        "Average main account balance over last 90 days",
        "Number of days till last recharge of main account",
        "Number of days till last recharge of data account",
        "Amount of last recharge of main account (in Indonesian Rupiah)",
        "Number of times main account got recharged in last 30 days",
        "Frequency of main account recharged in last 30 days",
        "Total amount of recharge in main account over last 30 days (in Indonesian Rupiah)",
       "Median of amount of recharges done in main account over last 30 days at user level (in Indonesian Rupiah)",
       "Median of main account balance just before recharge in last 30 days at user level (in Indonesian Rupiah)",
       "Number of times main account got recharged in last 90 days",
       "Frequency of main account recharged in last 90 days",
       "Total amount of recharge in main account over last 90 days (in Indonesian Rupee)",
       "Median of amount of recharges done in main account over last 90 days at user level (in Indonesian Rupee)",
        "Median of main account balance just before recharge in last 90 days at user level (in Indonesian Rupee)",
       "Number of times data account got recharged in last 30 days",
       "Frequency of data account recharged in last 30 days",
       "Number of times data account got recharged in last 90 days",
       "Frequency of data account recharged in last 90 days",
       "Number of loans taken by user in last 30 days",
       "Total amount of loans taken by user in last 30 days",
       "maximum amount of loan taken by the user in last 30 days",
       "Median of amounts of loan taken by the user in last 30 days",
       "Number of loans taken by user in last 90 days",
       "Total amount of loans taken by user in last 90 days",
       "maximum amount of loan taken by the user in last 90 days",
       "Median of amounts of loan taken by the user in last 90 days",
       "Average payback time in days over last 30 days",
        "Average payback time in days over last 90 days",
       "telecom circle",
       "date"]



for i in range(len(info)):
    print(customers.columns[i]+" :\t"+info[i])
# Out:
# label :	Flag indicating whether the user paid back the credit amount within 5 days of issuing the loan{1:success, 0:failure}
# msisdn :	mobile number of user
# aon :	age on cellular network in days
# daily_decr30 :	Daily amount spent from main account, averaged over last 30 days (in Indonesian Rupiah)
# daily_decr90 :	Daily amount spent from main account, averaged over last 90 days (in Indonesian Rupiah)
# rental30 :	Average main account balance over last 30 days
# rental90 :	Average main account balance over last 90 days
# last_rech_date_ma :	Number of days till last recharge of main account
# last_rech_date_da :	Number of days till last recharge of data account
# last_rech_amt_ma :	Amount of last recharge of main account (in Indonesian Rupiah)
# cnt_ma_rech30 :	Number of times main account got recharged in last 30 days
# fr_ma_rech30 :	Frequency of main account recharged in last 30 days
# ...

# %%
# Representing the dimensionality of the DataFrame.
customers.shape
# Out:
# (209593, 36)

# %%
#viewing column labels of the DataFrame.
customers.columns
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
#check datatypes
customers.dtypes
# Out:
# label                            int64
# msisdn                          object
# aon                            float64
# daily_decr30                   float64
# daily_decr90                   float64
# rental30                       float64
# rental90                       float64
# last_rech_date_ma              float64
# last_rech_date_da              float64
# last_rech_amt_ma                 int64
# cnt_ma_rech30                    int64
# fr_ma_rech30                   float64
# sumamnt_ma_rech30              float64
# medianamnt_ma_rech30           float64
# medianmarechprebal30           float64
# cnt_ma_rech90                    int64
# fr_ma_rech90                     int64
# sumamnt_ma_rech90                int64
# medianamnt_ma_rech90           float64
# medianmarechprebal90           float64
# cnt_da_rech30                  float64
# fr_da_rech30                   float64
# cnt_da_rech90                    int64
# fr_da_rech90                     int64
# ...

# %%
#check datatypes in orders
customers.columns.to_series().groupby(customers.dtypes).groups
# Out:
# {dtype('int64'): Index(['label', 'last_rech_amt_ma', 'cnt_ma_rech30', 'cnt_ma_rech90',
#         'fr_ma_rech90', 'sumamnt_ma_rech90', 'cnt_da_rech90', 'fr_da_rech90',
#         'cnt_loans30', 'amnt_loans30', 'amnt_loans90', 'maxamnt_loans90'],
#        dtype='object'),
#  dtype('float64'): Index(['aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
#         'last_rech_date_ma', 'last_rech_date_da', 'fr_ma_rech30',
#         'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#         'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#         'fr_da_rech30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#         'medianamnt_loans90', 'payback30', 'payback90'],
#        dtype='object'),
#  dtype('<M8[ns]'): Index(['pdate'], dtype='object'),
#  dtype('O'): Index(['msisdn', 'pcircle'], dtype='object')}

# %%
#viewing number of distinct observations
customers.nunique()
# Out:
# label                        2
# msisdn                  186243
# aon                       4507
# daily_decr30            146328
# daily_decr90            155483
# rental30                131338
# rental90                139036
# last_rech_date_ma         1186
# last_rech_date_da         1174
# last_rech_amt_ma            70
# cnt_ma_rech30               71
# fr_ma_rech30              1083
# sumamnt_ma_rech30        15141
# medianamnt_ma_rech30       510
# medianmarechprebal30     23907
# cnt_ma_rech90              110
# fr_ma_rech90                89
# sumamnt_ma_rech90        31771
# medianamnt_ma_rech90       608
# medianmarechprebal90     22694
# cnt_da_rech30             1066
# fr_da_rech30              1072
# cnt_da_rech90               27
# fr_da_rech90                46
# cnt_loans30                 40
# amnt_loans30                48
# maxamnt_loans30           1050
# medianamnt_loans30           6
# cnt_loans90               1110
# amnt_loans90                69
# ...

# %%
# To find duplicates
customers.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 209588    False
# 209589    False
# 209590    False
# 209591    False
# 209592    False
# Length: 209593, dtype: bool

# %%
# Remove duplicates values
customers.drop_duplicates(inplace=True)

# %%
#Re-Check shape 
customers.shape
# Out:
# (209592, 36)

# %%
#checking null values
customers.isnull().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# ...

# %%
#drop all row which Number of loans taken by user in last 90 days equal zero
index_names = customers[(customers['cnt_loans90'] == 0)].index
customers.drop(index_names, inplace = True)

# %%
#drop all row which Number of loans taken by user in last 30 days equal zero
index_names = customers[(customers['cnt_loans30'] == 0)].index
customers.drop(index_names, inplace = True)

# %%
#drop all row which age on cellular network in days less thenor equal zero  
index_names = customers[(customers['aon'] <= 0)].index
customers.drop(index_names, inplace = True)

# %%
#drop all row which Daily amount spent from main account less then zero
index_names = customers[(customers['daily_decr90'] < 0)].index
customers.drop(index_names, inplace = True)

# %%
#drop all row which Average main account balance less then or equal to -6
index_names = customers[(customers['rental90'] <= -6)].index
customers.drop(index_names, inplace = True)

# %%
#check descriptive statistics.
customers.describe().T
# Out:
#                          count          mean           std     min  \
# label                 197226.0      0.879788      0.325211    0.00
# aon                   197226.0   8117.676582  75699.805957    1.00
# daily_decr30          197226.0   5537.335737   9349.104676    0.00
# daily_decr90          197226.0   6252.166618  11075.618152    0.00
# rental30              197226.0   2779.772240   4306.470647   -5.95
# rental90              197226.0   3583.670248   5758.815650   -5.95
# last_rech_date_ma     197226.0   3798.207916  54213.085019  -29.00
# last_rech_date_da     197226.0   3767.262992  53783.986153  -29.00
# last_rech_amt_ma      197226.0   2004.444723   2257.871283    0.00
# cnt_ma_rech30         197226.0      4.089679      4.300371    0.00
# fr_ma_rech30          197226.0   3759.666393  53822.837294    0.00
# sumamnt_ma_rech30     197226.0   7701.304078   9691.179202    0.00
# medianamnt_ma_rech30  197226.0   1763.323819   1956.478969    0.00
# ...

# %%
#from dates we can get monthly ,daily ,yearly which can help in data analysis
customers['month']=customers['pdate'].dt.month
customers['year']=customers['pdate'].dt.year
customers['day']=customers['pdate'].dt.day
customers.drop('pdate',inplace=True,axis=1)

# %%
#checking labelwise dataframe

#cust_zero=customers.loc[customers['label'] == 0]
#cust_one=customers.loc[customers['label'] == 1]

# %%
#cust_zero.shape,cust_one.shape

# %%
#drop unused attribute
customers.drop('msisdn',axis=1,inplace=True)

# %%
# Correlation Plot
corrmat = customers.corr()

#Set uo the matplolib figure
f, ax = plt.subplots(figsize=(25,25))

#Draw the heatmap using seaborn
colormap = plt.cm.RdYlGn_r
sns.heatmap(corrmat, linewidths=0.1, cmap = colormap, linecolor = 'White', vmax=0.8, annot=True)

# %%
# Check for label
FIGURE_SIZE = (8,8)
plt.title("Ratio of label", color = 'blue', fontsize = 20)
customers['label'].value_counts().plot.pie(figsize=FIGURE_SIZE, autopct = '%1.1f%%')

# %%
# check pcircle wise label value
sns.countplot('pcircle', hue='label', data=customers)
plt.tight_layout()
plt.show()

# %%
# check year wise label value
sns.countplot('year', hue='label', data=customers)
plt.tight_layout()
plt.show()

# %%
# check month wise label value
sns.countplot('month', hue='label', data=customers)
plt.tight_layout()
plt.show()

# %%
# check day wise label value
sns.countplot('day', hue='label', data=customers)
plt.tight_layout()
plt.show()

# %%
# representation all numerical values using histogram
customers.hist(figsize=(20,20))
plt.show()

# %%
# representation in lineplot of Daily amount spent from main account, averaged over last 30 days and averaged over last 90 days over label
f, ax = plt.subplots(figsize=(12,12))
sns.lineplot(x = 'daily_decr30', y='daily_decr90', hue='label', data=customers)

# %%
# representation in lineplot of Number of loans taken by user in last 30 days and payback in 30 days over label
f, ax = plt.subplots(figsize=(12,12))
sns.lineplot(x = 'cnt_loans30', y='payback30', hue='label', data=customers)

# %%
# representation in lineplot of Number of loans taken by user in last 90 days and payback in 90 days over label
f, ax = plt.subplots(figsize=(12,12))
sns.lineplot(x = 'cnt_loans90', y='payback90', hue='label', data=customers)

# %%
# representation in scatterplot of Number of loans taken by user in last 30 days and payback in 30 days over label
f, ax = plt.subplots(figsize=(12,12))
sns.scatterplot(x=customers['cnt_loans30'],y=customers['payback30'],hue='label',data=customers)
plt.show()

# %%
# representation in scatterplot of Number of loans taken by user in last 90 days and payback in 90 days over label
f, ax = plt.subplots(figsize=(12,12))
sns.scatterplot(x=customers['cnt_loans90'],y=customers['payback90'],hue='label',data=customers)
plt.show()

# %%
#label encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
customers['pcircle'] = le.fit_transform(customers['pcircle']) #label encoding

# %%
# importing libary Handling Imbalanced 
from imblearn.under_sampling import NearMiss

# %%
# separate target variable
Y = pd.DataFrame(customers['label'],columns=['label'])

# %%
# separate independent variables
X = customers.drop('label',axis=1,inplace=True)

# %%
X=customers

# %%
# Implementing Undersampling for Handling Imbalanced 
nm = NearMiss()
X_res,y_res=nm.fit_sample(X,Y)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_std = sc.fit_transform(X_res)

# %%
X = pd.DataFrame(X_std,columns=X.columns)
X.shape
# Out:
# (47418, 36)

# %%
#Prediction - Classification Algorithms
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,roc_curve,auc

# %%
#Split the data into train and test set for classifcation predictions

from sklearn.model_selection import train_test_split,cross_val_score
x_train,x_test,y_train,y_test=train_test_split(X,y_res,test_size=0.3,random_state=9,stratify=y_res)
x_train.shape, y_train.shape, x_test.shape
# Out:
# ((33192, 36), (33192, 1), (14226, 36))

# %%
Model=[]
score=[]
cvs=[]
rocscore=[]

# %%
KNN=KNeighborsClassifier(n_neighbors=6)
Model.append('KNeighborsClassifier')
KNN.fit(x_train,y_train)
print(KNN)
pre=KNN.predict(x_test)
AS=accuracy_score(y_test,pre)
print('Accuracy_score= ',AS)
score.append(AS*100)
sc=cross_val_score(KNN,X,y_res,cv=5,scoring='accuracy').mean()
print('Cross_val_score=',sc)
cvs.append(sc*100)
false_positive_rate,true_positive_rate,thresholds=roc_curve(y_test,pre)
roc_auc=auc(false_positive_rate,true_positive_rate)
print('roc_auc_score= ',roc_auc)
rocscore.append(roc_auc*100)
print('classification_report\n',classification_report(y_test,pre),'\n')
cm=confusion_matrix(y_test,pre)
print('Confusion Matrix\n',cm,'\n')
plt.figure(figsize=(10,40))
plt.subplot(911)
plt.title('KNeighborsClassifier')
plt.plot(false_positive_rate,true_positive_rate,label='AUC=%0.2f'%roc_auc)
plt.plot([0,1],[0,1],'r--')
plt.legend(loc='lower right')
plt.ylabel('True Positive rate')
plt.xlabel('false Positive rate')
print('\n\n')
# Out:
# KNeighborsClassifier(n_neighbors=6)
# Accuracy_score=  0.7842682412484184
# Cross_val_score= 0.7226603218536686
# roc_auc_score=  0.7842682412484183
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.78      0.80      0.79      7113
#            1       0.79      0.77      0.78      7113
#
#     accuracy                           0.78     14226
#    macro avg       0.78      0.78      0.78     14226
# weighted avg       0.78      0.78      0.78     14226
#
#
# Confusion Matrix
#  [[5686 1427]
#  [1642 5471]]

# %%
SV=SVC()
Model.append('SVC')
SV.fit(x_train,y_train)
print(SV)
pre=SV.predict(x_test)
print('\n')
AS=accuracy_score(y_test,pre)
print('Accuracy_score= ',AS)
score.append(AS*100)
sc=cross_val_score(SV,X,y_res,cv=5,scoring='accuracy').mean()
print('Cross_val_score=',sc,'\n')
cvs.append(sc*100)
print('\n')
false_positive_rate,true_positive_rate,thresholds=roc_curve(y_test,pre)
roc_auc=auc(false_positive_rate,true_positive_rate)
print('roc_auc_score= ',roc_auc,'\n')
rocscore.append(roc_auc*100)
print('classification_report\n',classification_report(y_test,pre),'\n')
cm=confusion_matrix(y_test,pre)
print('Confusion Matrix\n',cm,'\n')
plt.figure(figsize=(10,40))
plt.subplot(911)
plt.title('SVC')
plt.plot(false_positive_rate,true_positive_rate,label='AUC=%0.2f'%roc_auc)
plt.plot([0,1],[0,1],'r--')
plt.legend(loc='lower right')
plt.ylabel('True Positive rate')
plt.xlabel('false Positive rate')
print('\n\n')
# Out:
# SVC()
#
#
# Accuracy_score=  0.7733024040489245
# Cross_val_score= 0.7068633750831085
#
#
#
# roc_auc_score=  0.7733024040489245
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.85      0.66      0.74      7113
#            1       0.72      0.89      0.80      7113
#
#     accuracy                           0.77     14226
#    macro avg       0.79      0.77      0.77     14226
# weighted avg       0.79      0.77      0.77     14226
#
#
# Confusion Matrix
#  [[4699 2414]
#  [ 811 6302]]

# %%
LR=LogisticRegression()
Model.append('LogisticRegression')
LR.fit(x_train,y_train)
print(LR)
pre=LR.predict(x_test)
print('\n')
AS=accuracy_score(y_test,pre)
print('Accuracy_score= ',AS)
score.append(AS*100)
sc=cross_val_score(LR,X,y_res,cv=5,scoring='accuracy').mean()
print('Cross_val_score=',sc,'\n')
cvs.append(sc*100)
#print('\n')
false_positive_rate,true_positive_rate,thresholds=roc_curve(y_test,pre)
roc_auc=auc(false_positive_rate,true_positive_rate)
print('roc_auc_score= ',roc_auc,'\n')
rocscore.append(roc_auc*100)
print('classification_report\n',classification_report(y_test,pre),'\n')
cm=confusion_matrix(y_test,pre)
print('Confusion Matrix\n',cm,'\n')
plt.figure(figsize=(10,40))
plt.subplot(911)
plt.title('LogisticRegression')
plt.plot(false_positive_rate,true_positive_rate,label='AUC=%0.2f'%roc_auc)
plt.plot([0,1],[0,1],'r--')
plt.legend(loc='lower right')
plt.ylabel('True Positive rate')
plt.xlabel('false Positive rate')
print('\n\n')
# Out:
# LogisticRegression()
#
#
# Accuracy_score=  0.7395613665120202
# Cross_val_score= 0.7242590338910541
#
# roc_auc_score=  0.7395613665120202
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.84      0.59      0.70      7113
#            1       0.69      0.89      0.77      7113
#
#     accuracy                           0.74     14226
#    macro avg       0.76      0.74      0.73     14226
# weighted avg       0.76      0.74      0.73     14226
#
#
# Confusion Matrix
#  [[4223 2890]
#  [ 815 6298]]

# %%
DT=DecisionTreeClassifier(random_state=6)
Model.append('DecisionTreeClassifier')
DT.fit(x_train,y_train)
print(DT)
pre=DT.predict(x_test)
print('\n')
AS=accuracy_score(y_test,pre)
print('Accuracy_score= ',AS)
score.append(AS*100)
sc=cross_val_score(DT,X,y_res,cv=5,scoring='accuracy').mean()
print('Cross_val_score=',sc,'\n')
cvs.append(sc*100)
print('\n')
false_positive_rate,true_positive_rate,thresholds=roc_curve(y_test,pre)
roc_auc=auc(false_positive_rate,true_positive_rate)
print('roc_auc_score= ',roc_auc,'\n')
rocscore.append(roc_auc*100)
print('classification_report\n',classification_report(y_test,pre),'\n')
cm=confusion_matrix(y_test,pre)
print('Confusion Matrix\n',cm,'\n')
plt.figure(figsize=(10,40))
plt.subplot(911)
plt.title('DecisionTreeClassifier')
plt.plot(false_positive_rate,true_positive_rate,label='AUC=%0.2f'%roc_auc)
plt.plot([0,1],[0,1],'r--')
plt.legend(loc='lower right')
plt.ylabel('True Positive rate')
plt.xlabel('false Positive rate')
print('\n\n')
# Out:
# DecisionTreeClassifier(random_state=6)
#
#
# Accuracy_score=  0.8331224518487277
# Cross_val_score= 0.7934547773184477
#
#
#
# roc_auc_score=  0.8331224518487277
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.83      0.84      0.83      7113
#            1       0.84      0.83      0.83      7113
#
#     accuracy                           0.83     14226
#    macro avg       0.83      0.83      0.83     14226
# weighted avg       0.83      0.83      0.83     14226
#
#
# Confusion Matrix
#  [[5957 1156]
#  [1218 5895]]

# %%
GNB=GaussianNB()
Model.append('GaussianNB')
GNB.fit(x_train,y_train)
print(GNB)
pre=GNB.predict(x_test)
print('\n')
AS=accuracy_score(y_test,pre)
print('Accuracy_score= ',AS)
score.append(AS*100)
sc=cross_val_score(GNB,X,y_res,cv=5,scoring='accuracy').mean()
print('Cross_val_score=',sc,'\n')
cvs.append(sc*100)
print('\n')
false_positive_rate,true_positive_rate,thresholds=roc_curve(y_test,pre)
roc_auc=auc(false_positive_rate,true_positive_rate)
print('roc_auc_score= ',roc_auc,'\n')
rocscore.append(roc_auc*100)
print('classification_report\n',classification_report(y_test,pre),'\n')
cm=confusion_matrix(y_test,pre)
print('Confusion Matrix\n',cm,'\n')
plt.figure(figsize=(10,40))
plt.subplot(911)
plt.title('GaussianNB')
plt.plot(false_positive_rate,true_positive_rate,label='AUC=%0.2f'%roc_auc)
plt.plot([0,1],[0,1],'r--')
plt.legend(loc='lower right')
plt.ylabel('True Positive rate')
plt.xlabel('false Positive rate')
print('\n\n')
# Out:
# GaussianNB()
#
#
# Accuracy_score=  0.6329256291297624
# Cross_val_score= 0.6323128052672382
#
#
#
# roc_auc_score=  0.6329256291297624
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.98      0.27      0.42      7113
#            1       0.58      1.00      0.73      7113
#
#     accuracy                           0.63     14226
#    macro avg       0.78      0.63      0.58     14226
# weighted avg       0.78      0.63      0.58     14226
#
#
# Confusion Matrix
#  [[1924 5189]
#  [  33 7080]]

# %%
RFC=RandomForestClassifier(n_estimators=1000,random_state=0)
Model.append('RandomForestClassifier')
RFC.fit(x_train,y_train)
print(RFC)
pre=RFC.predict(x_test)
print('\n')
AS=accuracy_score(y_test,pre)
print('Accuracy_score= ',AS)
score.append(AS*100)
sc=cross_val_score(RFC,X,y_res,cv=5,scoring='accuracy').mean()
print('Cross_val_score=',sc,'\n')
cvs.append(sc*100)
print('\n')
false_positive_rate,true_positive_rate,thresholds=roc_curve(y_test,pre)
roc_auc=auc(false_positive_rate,true_positive_rate)
print('roc_auc_score= ',roc_auc,'\n')
rocscore.append(roc_auc*100)
print('classification_report\n',classification_report(y_test,pre),'\n')
cm=confusion_matrix(y_test,pre)
print('Confusion Matrix\n',cm,'\n')
plt.figure(figsize=(10,40))
plt.subplot(911)
plt.title('RandomForestClassifier')
plt.plot(false_positive_rate,true_positive_rate,label='AUC=%0.2f'%roc_auc)
plt.plot([0,1],[0,1],'r--')
plt.legend(loc='lower right')
plt.ylabel('True Positive rate')
plt.xlabel('false Positive rate')
print('\n\n')
# Out:
# RandomForestClassifier(n_estimators=1000, random_state=0)
#
#
# Accuracy_score=  0.8866160551103613
# Cross_val_score= 0.8273449462918239
#
#
#
# roc_auc_score=  0.8866160551103613
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.89      0.88      0.89      7113
#            1       0.88      0.90      0.89      7113
#
#     accuracy                           0.89     14226
#    macro avg       0.89      0.89      0.89     14226
# weighted avg       0.89      0.89      0.89     14226
#
#
# Confusion Matrix
#  [[6245  868]
#  [ 745 6368]]

# %%
result=pd.DataFrame({'Model':Model,'Accuracy_score':score,'Cross_val_score':cvs,'Roc_auc_curve':rocscore})
result
# Out:
#                     Model  Accuracy_score  Cross_val_score  Roc_auc_curve
# 0    KNeighborsClassifier       78.426824        72.266032      78.426824
# 1                     SVC       77.330240        70.686338      77.330240
# 2      LogisticRegression       73.956137        72.425903      73.956137
# 3  DecisionTreeClassifier       83.312245        79.345478      83.312245
# 4              GaussianNB       63.292563        63.231281      63.292563
# 5  RandomForestClassifier       88.661606        82.734495      88.661606

# %%
#from sklearn.externals 
import joblib
joblib.dump(RFC,'Micro_Credit_Model.obj')
# Out:
# ['Micro_Credit_Model.obj']

# %%
model=joblib.load('Micro_Credit_Model.obj')

# %%
result=pd.DataFrame(model.predict(x_test))

# %%
result.to_csv('Micro-Credit_Defaulter_prdictresults.csv')
